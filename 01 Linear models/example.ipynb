# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

from logistic_regression import LogisticRegression

# %%
data = load_iris()
X = data.data[data.target != 2]
y = data.target[data.target != 2]

print("X:", X.shape)
# Out:
# X: (100, 4)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42, stratify=y)
X_train.shape[0], X_test.shape[0]
# Out:
# (50, 50)

# %%
model = LogisticRegression(lr=0.001, max_epochs=100, batch_size=4, verbose=True, tol=0.0005)
model.fit(X_train, y_train)
# Out:
# Epoch    0 | Loss: 0.6851
# Epoch   10 | Loss: 0.6266
# Epoch   20 | Loss: 0.5792
# Epoch   30 | Loss: 0.5375
# Epoch   40 | Loss: 0.5004
# Epoch   50 | Loss: 0.4672
# Epoch   60 | Loss: 0.4375
# Epoch   70 | Loss: 0.4108
# Epoch   80 | Loss: 0.3868
# Epoch   90 | Loss: 0.3653

# %%
y_pred = model.predict(X_test)
accuracy = (y_test == y_pred).mean()
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0
